# %%
import numpy as np
import scipy
from scipy import ndimage
import matplotlib.pyplot as plt
from PIL import Image

fname = 'IMG_5425.JPG'
image = Image.open(fname).convert("L")
arr = np.asarray(image)
print(arr.shape)
#arr = ndimage.interpolation.affine_transform(arr, arr.transpose, output_shape=(128, 128))
plt.imshow(arr, cmap='gray')
plt.show()
# Out:
# (960, 1280)

# %%
img=scipy.misc.face()
#imshow(img,cmap=cm.gray);show()
centre=0.5*array(img.shape)
a=15.0*pi/180.0
rot=array([[cos(a),sin(a)],[-sin(a),cos(a)]])
#offset=(centre-centre.dot(rot)).dot(linalg.inv(rot))
rotimg=scipy.ndimage.interpolation.affine_transform(
    img,rot,order=2,cval=0.0,output=float32
)
imshow(rotimg,cmap=cm.gray);show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-056516b828cb> in <module>()
#       6 #offset=(centre-centre.dot(rot)).dot(linalg.inv(rot))
#       7 rotimg=scipy.ndimage.interpolation.affine_transform(
# ----> 8     img,rot,order=2,cval=0.0,output=float32
#       9 )
#      10 imshow(rotimg,cmap=cm.gray);show()
#
# /usr/lib/python2.7/dist-packages/scipy/ndimage/interpolation.pyc in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     401         raise RuntimeError('no proper affine matrix provided')
#     402     if matrix.shape[0] != input.ndim:
# --> 403         raise RuntimeError('affine matrix has wrong number of rows')
#     404     if matrix.ndim == 2 and matrix.shape[1] != output.ndim:
#     405         raise RuntimeError('affine matrix has wrong number of columns')
#
# RuntimeError: affine matrix has wrong number of rows
