# %%
from othello_rules import *
from othello_net import *
from tensorflow.python.framework import ops
from datetime import datetime
from example_states import *
from feature_extractor import *
from training_utils import *
import numpy as np
np.set_printoptions(suppress=True)

# %%
def value_error(data_path, sess, diagnostics=False):
    errors = []
    validation_matches = get_all_matches(data_path)
    #XXX: Delete this line when testing is faster
    validation_matches = validation_matches[0:30]
    for i in range(len(validation_matches)):
        if diagnostics:
            print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game")
        match = validation_matches[i]
        raw_match_movelist = match[8:]
        unpacked_movelist = unpack('b'*60, raw_match_movelist)
        black_score = match[6]
        unpacked_black_score = unpack('b', black_score)
        winner = -1 if unpacked_black_score[0] > 32 else 1
        board = initialize_game()
        player = -1
        
        if diagnostics:
            print(unpacked_black_score)
            print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is " + str(winner))
        movenr = 0
        for move in unpacked_movelist:
            if move == 0:
                break
            feature_path = 'cache/validation/features/features_' + str(i) + "_" + str(move) + ".npy"
            label_path = 'cache/validation/labels/labels_' + str(i) + "_" + str(move) + ".npy"
            if os.path.isfile(feature_path) and os.path.isfile(label_path):
                features = np.load(feature_path)
            else:
                features = board_to_input(board, player)
            input_batch = [features]
            #s = 1 if player * (-1) == winner else 0
            if winner == -1:
                r = ([0, 1])
                #r = [[0]]
            else:
                r = ([1, 0])
                #r = [[1]]
            label_batch = [r]
            

            if diagnostics and movenr > 52:
                estimate = sess.run(score_out, feed_dict={img_data:input_batch, keep_prob:1.0})
                predictions = sess.run(score_out, feed_dict={img_data:input_batch, keep_prob:1.0})
                predic = predictions[0][0][0]
                prediction = list_softmax(predic)
                print("-new state-")
                print("actual value: " + str(r))
                #print("score_out: " + str(estimate))
                print("predictions: " + str(prediction))
            movenr += 1
            error = sess.run(loss, feed_dict={img_data:input_batch, ground_truths: label_batch, keep_prob:1.0})
            errors.append(error)
            board = make_move(board, move, player)
            if player is 1:
                player = -1
            else:
                player = 1
            legal_moves = find_legal_moves(board, player)
            if len(legal_moves) == 0:
                if player is 1:
                    player = -1
                else:
                    player = 1
                    
        if np.count_nonzero(board) == 64:
            error = sess.run(loss, feed_dict={img_data:input_batch, ground_truths: label_batch, keep_prob:1.0})
            errors.append(error)
            predic = sess.run(score_out, feed_dict={img_data:input_batch, ground_truths: label_batch, keep_prob:1.0})
            predic = predic[0][0][0]
            prediction = list_softmax(predic)
            if diagnostics:
                print("target is ")
                print(r)
                print("prediction is:")
                print(prediction)
    return np.sum(errors) / len(errors)

def list_softmax(x):
    """Compute softmax values for each sets of scores in x."""
    sf = np.exp(x)
    sf = sf/np.sum(sf, axis=0)
    return sf

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

def lrelu(x, leak=0.2, name="lrelu"):
    return tf.maximum(x, leak*x)

def conv_nonparams2(tensor_input, conv_weights, conv_biases, keep_prob):
    conv_in = conv(tensor_input, conv_weights)
    conv_relu = lrelu(conv_in + conv_biases)
    conv_drop = tf.nn.dropout(conv_relu, keep_prob)
    return conv_drop

def conv_weights2(i, o):
    k = 2
    shape = [k, k, i, o]
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def conv_nonparams3(tensor_input, conv_weights, conv_biases, keep_prob):
    conv_in = conv(tensor_input, conv_weights, "VALID")
    conv_relu = lrelu(conv_in + conv_biases)
    conv_drop = tf.nn.dropout(conv_relu, keep_prob)
    return conv_drop

def create_value_net():
    with tf.name_scope("value_network"):
        img_data = tf.placeholder(tf.float32, shape=[None, 8, 8, 28], name="img_data")
        keep_prob = tf.placeholder(tf.float32, name="keep_prob")
        #convolutional layers 
        i = 28; o = 32;
        conv1_weights = conv_weights(i, o)
        conv1_biases = conv_biases(o)
        conv1_out = conv_nonparams2(img_data, conv1_weights, conv1_biases, keep_prob)
        #pool1 = max_pool_2x2(conv1_out)
        i = o; o = 32;
        conv2_weights = conv_weights(i, o)
        conv2_biases = conv_biases(o)
        conv2_out = conv_nonparams2(conv1_out, conv2_weights, conv2_biases, keep_prob)
        #pool2 = max_pool_2x2(conv2_out)
        i = o; o = 32;
        conv3_weights = conv_weights2(i, o)
        conv3_biases = conv_biases(o)
        conv3_out = conv_nonparams2(conv2_out, conv3_weights, conv3_biases, keep_prob)
        
        i = o; o = 32;
        conv4_weights = conv_weights2(i, o)
        conv4_biases = conv_biases(o)
        conv4_out = conv_nonparams2(conv3_out, conv4_weights, conv4_biases, keep_prob)
        

        
        k = 1; i = o; o = 2;
        s_weights = weight_variable([k, k, i, o])
        s_biases = bias_variable([o])
        s_out = conv_nonparams(conv4_out, s_weights, s_biases, keep_prob)
        
        k = 8; i = o; o = 2;
        score_weights = weight_variable([k, k, i, o])
        score_biases = bias_variable([o])
        score_out = conv_nonparams3(s_out, score_weights, score_biases, keep_prob)
        score_out_flat = tf.reshape(score_out, [-1, o])
        #final layer
        #Don't actually use this layer here
        predictions = softmax(score_out, o)

        #training block:
        label = tf.placeholder(tf.float32, shape=[None, 2], name="ground_truths")
        learn_rate = tf.placeholder(tf.float32, name="eta")
        
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(score_out_flat, label))
        policy_network_variables = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES)
        reg_loss = tf.reduce_sum([tf.reduce_sum(tf.square(x)) for x in policy_network_variables])
        optimizer = tf.train.AdamOptimizer(learn_rate)
        train_step = optimizer.minimize(loss)
        sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
        return sess.graph, img_data, train_step, optimizer, label, loss, predictions, keep_prob, learn_rate, score_out

    # MAKE SURE that the topology of this network is the same as the policy network!

# %%
ops.reset_default_graph()
graph, img_data, train_step, optimizer, ground_truths, loss, pred_up, keep_prob, learn_rate, score_out = create_value_net()
saver = tf.train.Saver()
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
init_op = tf.initialize_all_variables()
sess.run(init_op)
#nopool7 gat fundið hver sigrar leiki, 0.2~ loss

# Prófa noends9 upp á sanity checks

# "models/sl-v/noends9.ckpt.b" hefur 0.238 end state loss og notar ekki bara end-states

# >>>>> "models/sl-v/players_g.ckpt" hefur 0.544 all state loss og notar alltalltallt
# Þjálfaði aðallega í 1e-5 eða svo 

current_model = "models/sl-v/players_g.ckpt"
if os.path.isfile(current_model):
    saver.restore(sess, current_model)
validation_path = "validation/"
matches = get_all_matches('training/')
print(len(matches))

# Byrjum þjálfunina
print("start training")
#print("starting error:" + str(avg_error(validation_path, sess)))
#print('%s: Step %d: Prediction accuracy = %.2f' % (datetime.now(), 0,
#                                                      prediction_accuracy()/float(60)))
diagn = True
if diagn:
    iterations = 1
else:
    iterations = len(matches)
prev_stop = 15000
#upper_limit = np.max(prev_stop+iterations, len(matches))
probs = 1
eta = 5e-6
input_batch = []
label_batch = []
for i in range(prev_stop, prev_stop+iterations):
    if i > 35000 and i < 40000:
        continue
    #TODO: Skrifa þetta fall
    #input_batch, label_batch = prepare_train_batch(train_ids, batch_size, do_flips, do_rots, data_path)
    current_match = matches[i]
    raw_match_movelist = current_match[8:]
    unpacked_movelist = unpack('b'*60, raw_match_movelist)
    black_score = current_match[6]
    unpacked_black_score = unpack('b', black_score)
    
    #XXX: Temporary check for the value network, do this properly later
    if unpacked_black_score[0] > 32:
        winner = -1
    else:
        winner = 1
    
    board = initialize_game()
    training_stability = np.zeros((8,8))
    player = -1
    
    # One training batch is all the data from one match
    if winner == -1:
        r = ([0, 1])
    else:
        r = ([1, 0])
    
    for move in unpacked_movelist:
        if move == 0:
            break

        if np.random.rand()>0.0:
            feature_path = 'cache/training/features/features_' + str(i) + "_" + str(move) + ".npy"
            label_path = 'cache/training/labels/labels_' + str(i) + "_" + str(move) + ".npy"
            if os.path.isfile(feature_path) and os.path.isfile(label_path):
                try:
                    features = np.load(feature_path)
                    label = np.load(label_path)
                except:
                    print("data corruption in match " + str(i))
                    features = board_to_input(board, player)
                    label = prepare_data(move_to_label(move))
            else:
                features = board_to_input(board, player)
                label = prepare_data(move_to_label(move))
            features = np.array(features)
            input_batch.append(features)
            label_batch.append(r)
            
            features_upright = flip_features(features, 'upright')
            input_batch.append(features_upright)
            label_batch.append(r)

            # Then the other diagonal
            features_upleft = flip_features(features, 'upleft')
            input_batch.append(features_upleft)
            label_batch.append(r)

            # Then both diagonals
            features_both = flip_features(features, 'both')
            input_batch.append(features_both)
            label_batch.append(r)

        board = make_move(board, move, player)
        if player is 1:
            player = -1
        else:
            player = 1
        legal_moves = find_legal_moves(board, player)
        if len(legal_moves) == 0:
            if player is 1:
                player = -1
            else:
                player = 1
    #print(features)
    #input_batch.append(features)
    #label_batch.append(r)
    if len(input_batch) > 128:
        _, loss_ = sess.run([train_step, loss],
                               feed_dict={img_data:input_batch,
                                                ground_truths: label_batch,
                                                keep_prob:probs,
                                                learn_rate:eta})
        input_batch = []
        label_batch = []
    #print("score out is")
    #print(loss_)

    if (i % 1000 is 0) and (i > 0) or (i+1) == (iterations+prev_stop) or (i % 1000 is 0):  
        value_loss = value_error(validation_path, sess, diagn)
        print('%s, Step %d, Loss = %.6f' % (datetime.now().strftime("%d. %b %H:%M:%S"), i,
                                                                          value_loss))
        save_path = saver.save(sess, current_model + '.b')
        if value_loss < 0.24:
            break

print("done")
# Out:
# 117298
# start training
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (30,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.8552413  0.1447587]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.78976423  0.21023579]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.91221136  0.08778862]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.85521269  0.14478731]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.9327693   0.06723063]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.62111628  0.37888375]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93786466  0.06213535]
# target is
# [1, 0]
# prediction is:
# [ 0.93786466  0.06213535]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (29,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.69873744  0.3012625 ]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.8444795   0.15552051]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.83306229  0.16693769]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.90438569  0.09561431]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.96146685  0.03853314]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.69954902  0.30045101]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.91700304  0.08299696]
# target is
# [1, 0]
# prediction is:
# [ 0.91700304  0.08299696]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (19,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99884945  0.00115053]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99725682  0.00274321]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.92394042  0.07605962]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99364734  0.00635263]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99327248  0.00672752]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99172151  0.00827848]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.98644316  0.01355676]
# target is
# [1, 0]
# prediction is:
# [ 0.98644316  0.01355676]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (32,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.22298816  0.77701187]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.37690353  0.62309641]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.24646738  0.75353259]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.42860624  0.57139379]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.37410644  0.62589353]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.69515783  0.30484211]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.90606177  0.09393825]
# target is
# [1, 0]
# prediction is:
# [ 0.90606177  0.09393825]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (41,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.63117808  0.36882189]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.60761029  0.39238974]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.59905565  0.40094432]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.69091117  0.30908886]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.71758753  0.28241247]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.60813016  0.39186981]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.43498003  0.56501991]
# target is
# [0, 1]
# prediction is:
# [ 0.43498003  0.56501991]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (33,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.9957546   0.00424538]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.90571445  0.09428556]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.9653964   0.03460359]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.45793611  0.54206389]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.8723132   0.12768684]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.54240704  0.45759302]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.48294327  0.51705676]
# target is
# [0, 1]
# prediction is:
# [ 0.48294327  0.51705676]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (4,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99978936  0.00021063]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99984252  0.0001575 ]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93510944  0.06489054]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99963039  0.0003696 ]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.9290722   0.07092781]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99943727  0.00056275]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99837708  0.00162293]
# target is
# [1, 0]
# prediction is:
# [ 0.99837708  0.00162293]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (31,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.52752525  0.47247475]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.90022427  0.09977572]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.92565745  0.07434253]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.68054533  0.31945464]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.82379138  0.17620865]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.85534173  0.14465825]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.91874409  0.08125591]
# target is
# [1, 0]
# prediction is:
# [ 0.91874409  0.08125591]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (20,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93120772  0.06879225]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.8976289   0.10237104]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.97002548  0.02997447]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95548022  0.04451976]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99152982  0.00847018]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95511585  0.04488418]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.97950464  0.02049536]
# target is
# [1, 0]
# prediction is:
# [ 0.97950464  0.02049536]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (28,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93535644  0.06464352]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.97205955  0.02794051]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.97383159  0.0261684 ]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.71289176  0.28710821]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.96044284  0.03955715]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.88643277  0.11356723]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.94537944  0.05462054]
# target is
# [1, 0]
# prediction is:
# [ 0.94537944  0.05462054]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (38,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.17970403  0.82029599]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.57330763  0.42669234]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.07097993  0.92902005]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.46215302  0.53784704]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.396826    0.60317403]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.522241  0.477759]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.37481967  0.62518036]
# target is
# [0, 1]
# prediction is:
# [ 0.37481967  0.62518036]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (46,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.05123018  0.94876987]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.31691444  0.6830855 ]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.05208645  0.94791353]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.48233843  0.51766157]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.13905765  0.8609423 ]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.29064554  0.70935446]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.06312029  0.93687969]
# target is
# [0, 1]
# prediction is:
# [ 0.06312029  0.93687969]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (26,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.87659967  0.12340037]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.6761688   0.32383117]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.85081363  0.1491863 ]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.84261441  0.15738554]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.89930809  0.10069191]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.92042172  0.07957833]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.97972894  0.02027105]
# target is
# [1, 0]
# prediction is:
# [ 0.97972894  0.02027105]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (39,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.23253193  0.76746809]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.06854751  0.93145245]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.22929391  0.77070612]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.05236759  0.94763243]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.14716825  0.85283172]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.27396792  0.72603208]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.43925256  0.56074744]
# target is
# [0, 1]
# prediction is:
# [ 0.43925256  0.56074744]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (14,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93928212  0.06071787]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.98403043  0.01596957]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95362455  0.04637545]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95836395  0.04163606]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.97777838  0.02222159]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95118058  0.04881941]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99205202  0.00794795]
# target is
# [1, 0]
# prediction is:
# [ 0.99205202  0.00794795]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (33,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.67401969  0.32598028]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.45968699  0.54031307]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.83809096  0.1619091 ]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.41072392  0.58927608]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.66511172  0.33488828]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.76346147  0.23653851]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.61056072  0.38943925]
# target is
# [0, 1]
# prediction is:
# [ 0.61056072  0.38943925]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (31,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95410633  0.04589368]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.38933662  0.61066335]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.94311482  0.05688522]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.61475378  0.38524622]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95090026  0.04909977]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.97969621  0.0203038 ]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.50335532  0.49664462]
# target is
# [1, 0]
# prediction is:
# [ 0.50335532  0.49664462]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (30,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.70650351  0.29349646]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.8498776   0.15012236]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.70074338  0.29925665]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.81461817  0.18538186]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.78808367  0.21191634]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.63420463  0.36579531]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.67610043  0.32389957]
# target is
# [1, 0]
# prediction is:
# [ 0.67610043  0.32389957]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (27,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.71780056  0.28219944]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.88366354  0.11633652]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.78959888  0.21040118]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.85188514  0.14811482]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.89478308  0.10521698]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.7249496  0.2750504]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.97450656  0.02549345]
# target is
# [1, 0]
# prediction is:
# [ 0.97450656  0.02549345]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (39,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.22343504  0.77656496]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.07125727  0.92874271]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.39731282  0.60268724]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.27347812  0.72652191]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.57553852  0.42446148]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.48810029  0.51189971]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.49218038  0.50781959]
# target is
# [0, 1]
# prediction is:
# [ 0.49218038  0.50781959]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (31,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.55612409  0.44387591]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.42254502  0.57745498]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.7311306   0.26886937]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.69135255  0.30864742]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.73482352  0.26517645]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.66050661  0.33949345]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.88636625  0.11363376]
# target is
# [1, 0]
# prediction is:
# [ 0.88636625  0.11363376]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (23,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.89039123  0.10960873]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.92838043  0.07161961]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.88639712  0.11360288]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.89228106  0.10771896]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.91861641  0.08138361]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.98803669  0.01196337]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.94106627  0.05893376]
# target is
# [1, 0]
# prediction is:
# [ 0.94106627  0.05893376]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (21,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.71286207  0.28713796]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.83817101  0.16182898]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.8550328  0.1449672]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93999928  0.06000072]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.90458137  0.09541864]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93811399  0.06188606]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.9587788   0.04122121]
# target is
# [1, 0]
# prediction is:
# [ 0.9587788   0.04122121]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (32,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.85887253  0.14112747]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.88867754  0.11132251]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93778658  0.06221341]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.90810996  0.09189004]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.89857703  0.10142295]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.50538069  0.49461928]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.74798673  0.25201318]
# target is
# [1, 0]
# prediction is:
# [ 0.74798673  0.25201318]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (47,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.35468814  0.64531189]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.48931524  0.51068479]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.06626463  0.93373537]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.02755089  0.97244906]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.06253358  0.93746644]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.05475022  0.9452498 ]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.13524619  0.86475384]
# target is
# [0, 1]
# prediction is:
# [ 0.13524619  0.86475384]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (13,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95462     0.04537995]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99694097  0.00305909]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.92744201  0.07255799]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99679363  0.00320632]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.93182272  0.06817729]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.9896726   0.01032738]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.96102971  0.03897025]
# target is
# [1, 0]
# prediction is:
# [ 0.96102971  0.03897025]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (33,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is -1
# -new state-
# actual value: [0, 1]
# predictions: [ 0.31791788  0.68208212]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.15169957  0.84830046]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.38097367  0.6190263 ]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.34502032  0.65497971]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.66696334  0.33303672]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.61534852  0.38465142]
# -new state-
# actual value: [0, 1]
# predictions: [ 0.70976478  0.29023528]
# target is
# [0, 1]
# prediction is:
# [ 0.70976478  0.29023528]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (23,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.52569735  0.47430262]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.84367651  0.15632351]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.6785934   0.32140666]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.81837231  0.18162768]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.76362014  0.23637991]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99029976  0.00970022]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.96759582  0.0324042 ]
# target is
# [1, 0]
# prediction is:
# [ 0.96759582  0.0324042 ]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (24,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.72592902  0.27407092]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95303828  0.04696172]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99617165  0.00382837]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.99084997  0.00915003]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.94934767  0.0506523 ]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.98333043  0.01666956]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.95300376  0.04699625]
# target is
# [1, 0]
# prediction is:
# [ 0.95300376  0.04699625]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>new game
# (29,)
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>winner is 1
# -new state-
# actual value: [1, 0]
# predictions: [ 0.88022476  0.11977523]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.61889702  0.38110295]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.30917802  0.69082195]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.34240192  0.65759808]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.19099383  0.80900615]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.87071222  0.12928776]
# -new state-
# actual value: [1, 0]
# predictions: [ 0.72270936  0.27729064]
# target is
# [1, 0]
# prediction is:
# [ 0.72270936  0.27729064]
# 15. Oct 11:41:07, Step 15000, Loss = 0.544077
# done

# %%
# number of doom: 0.693147

# %%
board1 = initialize_game()
zeros = np.count_nonzero(board1)
print(zeros)
f = board_to_input(board1, -1)
black = np.ones((8,8,1))
print(featurez.shape)
addone = np.dstack((f, black))
print(addone.shape)

# %% [markdown]
# (?, 2)
# (?, 1, 1, 2)
# (?, 2)
# 117298
# start training
#
# First 1e-3 down to 0.4, then:
#
# start = 1e-4
#
# start training
# 14. Oct 16:55:09, Step 0, Loss = 0.349850
# 14. Oct 16:55:15, Step 100, Loss = 0.338470
# 14. Oct 16:55:20, Step 200, Loss = 0.296196
# 14. Oct 16:55:25, Step 300, Loss = 0.283280
# 14. Oct 16:55:31, Step 400, Loss = 0.310574
# 14. Oct 16:55:36, Step 500, Loss = 0.308730
# 14. Oct 16:55:41, Step 600, Loss = 0.269805
# 14. Oct 16:55:47, Step 700, Loss = 0.255041
# 14. Oct 16:55:52, Step 800, Loss = 0.255202
# 14. Oct 16:55:57, Step 900, Loss = 0.233139
# 14. Oct 16:56:03, Step 1000, Loss = 0.230880
# 14. Oct 16:56:08, Step 1100, Loss = 0.192403
#
# "models/sl-v/nopool12.ckpt"

# %% [markdown]
# "fewer"params and no leaky relu
#
# 4e-4
#
# 117298
# start training
# 14. Oct 18:42:53, Step 0, Loss = 0.669618
# 14. Oct 18:42:59, Step 100, Loss = 0.640104
# 14. Oct 18:43:05, Step 200, Loss = 0.627391
# 14. Oct 18:43:11, Step 300, Loss = 0.682312
# 14. Oct 18:43:19, Step 400, Loss = 0.622758
# 14. Oct 18:43:24, Step 500, Loss = 0.418528
# 14. Oct 18:43:29, Step 600, Loss = 0.381199
# 14. Oct 18:43:36, Step 700, Loss = 0.289413
# 14. Oct 18:43:43, Step 799, Loss = 0.283211
# done
#
# 1e-4
#
# 117298
# start training
# 14. Oct 18:44:43, Step 100, Loss = 0.294863
# 14. Oct 18:44:49, Step 200, Loss = 0.256158
# 14. Oct 18:44:57, Step 300, Loss = 0.362265
# 14. Oct 18:45:05, Step 400, Loss = 0.305164
# 14. Oct 18:45:12, Step 500, Loss = 0.302925
# 14. Oct 18:45:19, Step 600, Loss = 0.208198
# 14. Oct 18:45:27, Step 700, Loss = 0.212496
# 14. Oct 18:45:34, Step 800, Loss = 0.217972
# 14. Oct 18:45:35, Step 807, Loss = 0.203382
# done
